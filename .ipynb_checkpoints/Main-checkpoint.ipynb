# %%
import pandas as pd
import numpy as np
import datetime as dt # procces dmy

# %%
# !pip3 install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yfinance in c:\users\lamvu\appdata\roaming\python\python311\site-packages (0.2.28)
# Requirement already satisfied: pandas>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\lamvu\appdata\roaming\python\python311\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\lamvu\appdata\roaming\python\python311\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\lamvu\appdata\roaming\python\python311\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\programdata\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)

# %%
import yfinance as yf

# %%
AAPL = yf.download(tickers='AAPL',period='5y',interval = '1d')#take data apple company
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
AAPL.drop("Adj Close", axis = 1, inplace =True)#delete column adj close
AAPL
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2018-08-17   53.360001   54.487499   53.290001   54.395000  141708000
# 2018-08-20   54.525002   54.794998   53.777500   53.865002  121150800
# 2018-08-21   54.200001   54.297501   53.507500   53.759998  104639200
# 2018-08-22   53.525002   54.090000   53.459999   53.762501   76072400
# 2018-08-23   53.662498   54.262501   53.650002   53.872501   75532800
# ...                ...         ...         ...         ...        ...
# 2023-08-10  179.479996  180.750000  177.600006  177.970001   54686900
# 2023-08-11  177.320007  178.619995  176.550003  177.789993   51988100
# 2023-08-14  177.970001  179.690002  177.309998  179.460007   43675600
# 2023-08-15  178.880005  179.479996  177.050003  177.449997   43622600
# 2023-08-16  177.130005  178.539993  176.500000  176.570007   46876800
#
# [1257 rows x 5 columns]

# %%
TSLA = yf.download(tickers='TSLA',period='5y',interval = '1d')#take data Tesla company
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
TSLA.drop("Adj Close", axis = 1, inplace =True)#delete column adj close
TSLA
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2018-08-17   21.566668   21.784666   20.235332   20.366667  284379000
# 2018-08-20   19.446667   20.566668   19.213333   20.562668  261034500
# 2018-08-21   20.707333   21.652666   20.600000   21.459999  197583000
# 2018-08-22   21.391333   21.591999   20.978001   21.442667   89190000
# 2018-08-23   21.275999   21.821333   21.206667   21.340000   77209500
# ...                ...         ...         ...         ...        ...
# 2023-08-10  245.399994  251.800003  243.000000  245.339996  109498600
# 2023-08-11  241.770004  243.789993  238.020004  242.649994   98866600
# 2023-08-14  235.699997  240.660004  233.750000  239.759995   98595300
# 2023-08-15  238.729996  240.500000  232.610001  232.960007   88197600
# 2023-08-16  228.020004  233.970001  225.380005  225.600006  111996300
#
# [1257 rows x 5 columns]

# %%
GG = yf.download(tickers='GOOGL',period='5y',interval = '1d')#take data GOOGLE company
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
GG.drop("Adj Close", axis = 1, inplace =True)#delete column adj close
GG
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2018-08-17   61.102001   61.347500   60.200001   60.792500  33092000
# 2018-08-20   61.033001   61.295502   60.435001   61.097500  22218000
# 2018-08-21   61.151001   61.638000   60.751499   60.870499  23082000
# 2018-08-22   60.710999   61.326500   60.660999   61.087502  22296000
# 2018-08-23   60.993999   61.758499   60.967499   61.057999  24666000
# ...                ...         ...         ...         ...       ...
# 2023-08-10  131.320007  132.050003  129.449997  129.690002  20857800
# 2023-08-11  128.660004  129.929993  128.169998  129.559998  19569200
# 2018-08-21     54.200001   54.297501   53.507500   53.759998  104639200
# 2018-08-22     53.525002   54.090000   53.459999   53.762501   76072400
# 2018-08-23     53.662498   54.262501   53.650002   53.872501   75532800
# ...                  ...         ...         ...         ...        ...
# 2023-08-10    179.479996  180.750000  177.600006  177.970001   54686900
# 2023-08-11    177.320007  178.619995  176.550003  177.789993   51988100
# 2023-08-14    177.970001  179.690002  177.309998  179.460007   43675600
# 2023-08-15    178.880005  179.479996  177.050003  177.449997   43622600
# 2023-08-16    177.130005  178.539993  176.500000  176.570007   46876800
#
# Company Name        TSLA                                                 \
# Stock Info          Open        High         Low       Close     Volume
# Date
# 2018-08-17     21.566668   21.784666   20.235332   20.366667  284379000
# 2018-08-20     19.446667   20.566668   19.213333   20.562668  261034500
# 2018-08-21     20.707333   21.652666   20.600000   21.459999  197583000
# 2018-08-22     21.391333   21.591999   20.978001   21.442667   89190000
# 2018-08-23     21.275999   21.821333   21.206667   21.340000   77209500
# ...                  ...         ...         ...         ...        ...
# 2023-08-10    245.399994  251.800003  243.000000  245.339996  109498600
# 2023-08-11    241.770004  243.789993  238.020004  242.649994   98866600
# 2023-08-14    235.699997  240.660004  233.750000  239.759995   98595300
# 2023-08-15    238.729996  240.500000  232.610001  232.960007   88197600
# 2023-08-16    228.020004  233.970001  225.380005  225.600006  111996300
#
# Company Name          GG
# Stock Info          Open        High         Low       Close    Volume
# Date
# 2018-08-17     61.102001   61.347500   60.200001   60.792500  33092000
# 2018-08-20     61.033001   61.295502   60.435001   61.097500  22218000
# 2018-08-21     61.151001   61.638000   60.751499   60.870499  23082000
# 2018-08-22     60.710999   61.326500   60.660999   61.087502  22296000
# 2018-08-23     60.993999   61.758499   60.967499   61.057999  24666000
# ...                  ...         ...         ...         ...       ...
# 2023-08-10    131.320007  132.050003  129.449997  129.690002  20857800
# 2023-08-11    128.660004  129.929993  128.169998  129.559998  19569200
# 2023-08-14    129.389999  131.369995  128.960007  131.330002  24695600
# 2023-08-15    131.100006  131.419998  129.279999  129.779999  19770700
# 2023-08-16    128.699997  130.279999  127.870003  128.699997  25201200
#
# [1257 rows x 15 columns]

# %%
#max value close for every company
company_stocks.xs(key='Close',axis = 1,level='Stock Info').max()
# Out:
# Company Name
# AAPL    196.449997
# TSLA    409.970001
# GG      149.838501
# dtype: float64

# %%
#min value close for every company
company_stocks.xs(key='Close',axis = 1,level='Stock Info').min()
# Out:
# Company Name
# AAPL    35.547501
# TSLA    11.931333
# GG      49.233501
# dtype: float64

# %%
value_cp = pd.DataFrame()#ti xuat loi nhuan
value_cp.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for name in list_company:
    value_cp[name+' close_value'] = company_stocks[name]['Close'].pct_change()*100

value_cp.columns.names = ['info_cp',]
value_cp.head()
# Out:
# info_cp     AAPL close_value  TSLA close_value  GG close_value
# Date
# 2018-08-17               NaN               NaN             NaN
# 2018-08-20         -0.974352          0.962362        0.501707
# 2018-08-21         -0.194938          4.363885       -0.371539
# 2018-08-22          0.004655         -0.080765        0.356499
# 2018-08-23          0.204605         -0.478797       -0.048296

# %%
import seaborn as sns

sns.pairplot(value_cp);

# %%
company_stocks1 = pd.concat([AAPL,TSLA,GG],axis =0, keys =list_company)
data_frame1 = pd.DataFrame()
data_frame1 = company_stocks1['Close']
data_frame1 = data_frame1.reset_index()
data_frame1.columns = ['Name','Date','Money']
print(data_frame1)
# Out:
#       Name       Date       Money
# 0     AAPL 2018-08-17   54.395000
# 1     AAPL 2018-08-20   53.865002
# 2     AAPL 2018-08-21   53.759998
# 3     AAPL 2018-08-22   53.762501
# 4     AAPL 2018-08-23   53.872501
# ...    ...        ...         ...
# 3766    GG 2023-08-10  129.690002
# 3767    GG 2023-08-11  129.559998
# 3768    GG 2023-08-14  131.330002
# 3769    GG 2023-08-15  129.779999
# 3770    GG 2023-08-16  128.699997
#
# [3771 rows x 3 columns]

# %%
g = sns.pairplot(data_frame1,hue = 'Name',x_vars='Date',y_vars = 'Money');
for ax in g.axes.flat[:2]:
    ax.tick_params(axis='x', labelrotation=45)
g

# %% [markdown]
# ### vẽ biểu đồ phân phối chuẩn của các công ty

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,5));#set playout for chart
sns.distplot(value_cp.loc['2021-01-01':'2021-12-31']['AAPL close_value'],color = 'green',bins=100);
# Out:
# C:\Users\lamvu\AppData\Local\Temp\ipykernel_16828\4071850247.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(value_cp.loc['2021-01-01':'2021-12-31']['AAPL close_value'],color = 'green',bins=100);

# %%
plt.figure(figsize=(15,5));#set playout for chart
sns.distplot(value_cp.loc['2021-01-01':'2021-12-31']['TSLA close_value'],color = 'red',bins=100);
# Out:
# C:\Users\lamvu\AppData\Local\Temp\ipykernel_16828\1607543018.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(value_cp.loc['2021-01-01':'2021-12-31']['TSLA close_value'],color = 'red',bins=100);

# %%
plt.figure(figsize=(15,5));#set playout for chart
sns.distplot(value_cp.loc['2021-01-01':'2021-12-31']['GG close_value'],color = 'blue',bins=100);
# Out:
# C:\Users\lamvu\AppData\Local\Temp\ipykernel_16828\2915765001.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(value_cp.loc['2021-01-01':'2021-12-31']['GG close_value'],color = 'blue',bins=100);

# %%
plt.figure(figsize=(15,5));#set playout for chart
sns.distplot(value_cp.loc['2021-01-01':'2021-12-31']['AAPL close_value'],color = 'green',bins=100,hist=False);
sns.distplot(value_cp.loc['2021-01-01':'2021-12-31']['TSLA close_value'],color = 'red',bins=100,hist=False);
sns.distplot(value_cp.loc['2021-01-01':'2021-12-31']['GG close_value'],color = 'blue',bins=100,hist=False);
# Out:
# C:\Users\lamvu\AppData\Local\Temp\ipykernel_16828\2776618953.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(value_cp.loc['2021-01-01':'2021-12-31']['AAPL close_value'],color = 'green',bins=100,hist=False);
# C:\Users\lamvu\AppData\Local\Temp\ipykernel_16828\2776618953.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(value_cp.loc['2021-01-01':'2021-12-31']['TSLA close_value'],color = 'red',bins=100,hist=False);
# C:\Users\lamvu\AppData\Local\Temp\ipykernel_16828\2776618953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(value_cp.loc['2021-01-01':'2021-12-31']['GG close_value'],color = 'blue',bins=100,hist=False);
